# %%
# !pip install skimpy -q
import pandas as pd
from skimpy import skim


hd_link = 'https://raw.githubusercontent.com/fpineyro/homework-0/master/heart_disease.csv'
d_hd = pd.read_csv(hd_link)


print("Estadísticas del DataFrame:")
skim(d_hd)
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipykernel==6.17.1, but you have ipykernel 7.3.0 which is incompatible.
# notebook 6.5.7 requires jupyter-client<8,>=5.3.4, but you have jupyter-client 8.10.0 which is incompatible.
# Estadísticas del DataFrame:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# ...

# %%
##Ejercicio 2
print("primeros 5 registros:")
print(d_hd.head(5))

print("nÚltimos 5 ejercicios")
print(d_hd.tail(5))
# Out:
# primeros 5 registros:
#    age  gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 0   63    male           1                     145                233
# 1   67    male           4                     160                286
# 2   67    male           4                     120                229
# 3   37    male           3                     130                250
# 4   41  female           2                     130                204
#
#    fasting_blood_sugar  resting_electro  max_heart_rate  exer_angina  oldpeak  \
# 0                    1                2             150            0      2.3
# 1                    0                2             108            1      1.5
# 2                    0                2             129            1      2.6
# 3                    0                0             187            0      3.5
# 4                    0                2             172            0      1.4
#
# ...

# %%
##Ejercicio 3

print(d_hd[['age', 'heart_disease_severity']])
# Out:
#      age  heart_disease_severity
# 0     63                       0
# 1     67                       2
# 2     67                       1
# 3     37                       0
# 4     41                       0
# ..   ...                     ...
# 298   45                       1
# 299   68                       2
# 300   57                       3
# 301   57                       1
# 302   38                       0
#
# [303 rows x 2 columns]

# %%
##Ejercicio 4


filtro_colesterol = d_hd['serum_cholestoral'] > 250

print(d_hd.loc[filtro_colesterol, :])
# Out:
#      age  gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 1     67    male           4                     160                286
# 6     62  female           4                     140                268
# 7     57  female           4                     120                354
# 8     63    male           4                     130                254
# 11    56  female           2                     140                294
# ..   ...     ...         ...                     ...                ...
# 280   57    male           4                     110                335
# 281   47    male           3                     130                253
# 285   58    male           4                     114                318
# 291   55  female           2                     132                342
# 298   45    male           1                     110                264
#
#      fasting_blood_sugar  resting_electro  max_heart_rate  exer_angina  \
# ...

# %%
## ejercicio 5
print("valores nulos por columna:")
print(d_hd.isnull().sum())
# Out:
# valores nulos por columna:
# age                       0
# gender                    0
# chest_pain                0
# resting_blood_pressure    0
# serum_cholestoral         0
# fasting_blood_sugar       0
# resting_electro           0
# max_heart_rate            0
# exer_angina               0
# oldpeak                   0
# slope                     0
# num_vessels_flour         4
# thal                      2
# heart_disease_severity    0
# exter_angina              0
# has_heart_disease         0
# dtype: int64

# %%
## ejercicio 6

d_hd['thal'] = d_hd['thal'].fillna(999)

print("Nulos restantes en thal:", d_hd['thal'].isnull().sum())
# Out:
# Nulos restantes en thal: 0

# %%
##Ejercicio 7

filtro_combinado = (d_hd['age'] > 60) & (d_hd['serum_cholestoral'] > 250)
print(d_hd.loc[filtro_combinado, :])
# Out:
#      age  gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 1     67    male           4                     160                286
# 6     62  female           4                     140                268
# 8     63    male           4                     130                254
# 32    64    male           3                     140                335
# 42    71  female           2                     160                302
# 44    61  female           4                     130                330
# 48    65  female           3                     140                417
# 70    65  female           3                     155                269
# 71    67    male           4                     125                254
# 72    62    male           4                     120                267
# 75    65  female           3                     160                360
# 83    68    male           3                     180                274
# ...

# %%
##Ejercicio 8

slope_modificado = d_hd['slope'].replace({1: 'ascendente', 2: 'descendente'})
print(slope_modificado)
# Out:
# 0                3
# 1      descendente
# 2      descendente
# 3                3
# 4       ascendente
#           ...
# 298    descendente
# 299    descendente
# 300    descendente
# 301    descendente
# 302     ascendente
# Name: slope, Length: 303, dtype: object

# %%
##Ejercicio 9

d_hd['is_healthy'] = d_hd['heart_disease_severity'] == 0
print(d_hd)
# Out:
#      age  gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 0     63    male           1                     145                233
# 1     67    male           4                     160                286
# 2     67    male           4                     120                229
# 3     37    male           3                     130                250
# 4     41  female           2                     130                204
# ..   ...     ...         ...                     ...                ...
# 298   45    male           1                     110                264
# 299   68    male           4                     144                193
# 300   57    male           4                     130                131
# 301   57  female           2                     130                236
# 302   38    male           3                     138                175
#
#      fasting_blood_sugar  resting_electro  max_heart_rate  exer_angina  \
# ...

# %%
##Ejercicio 10

d_hd_clean = d_hd.copy()
d_hd_clean.dropna(inplace=True)


skim(d_hd_clean)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 299    │ │ int64       │ 11    │                                                          │
# │ │ Number of columns │ 17     │ │ float64     │ 3     │                                                          │
# │ └───────────────────┴────────┘ │ string      │ 2     │                                                          │
# ...
